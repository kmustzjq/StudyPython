# %% [markdown]
# # 这是一级标题
# ## 这是二级标题
# ### 这是三级标题

# %%
print("hello word")
a,b=1,2
for i in range(10):
    a+=i
    print("a:",a)
# Out:
# hello word
# a: 1
# a: 2
# a: 4
# a: 7
# a: 11
# a: 16
# a: 22
# a: 29
# a: 37
# a: 46

# %%
import numpy as np
from matplotlib import pyplot as plt
#a=np.array([[1,2,3],[4,5,6]])
figrue1=plt.figure(1,facecolor='green')
a1=plt.subplot(221)
a1.plot(np.arange(1,11),np.random.rand(10),'r-d')
plt.title("random test")
plt.subplot(222)
plt.plot(np.arange(1,11),np.random.rand(10),'b-*')
plt.subplot(223)
plt.plot(np.arange(1,11),np.random.rand(10),'y-')
plt.subplot(224)
plt.plot(np.arange(1,11),np.random.rand(10),'r:o')


plt.show()

# %%
import matplotlib.pyplot as plt
#创建自定义图像
fig=plt.figure(figsize=(4,3),facecolor='blue')
plt.show()
